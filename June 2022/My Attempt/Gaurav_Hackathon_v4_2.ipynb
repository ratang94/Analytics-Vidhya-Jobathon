# %%
# !pip install pycaret[full]
# !pip install xgboost
# !pip uninstall scikit-learn -y
# !pip install -U pycaret scikit-learn
# !pip install markupsafe==2.0.1

# %%
#Importing Required Stuff
import pandas as pd
import numpy as np
# !pip install -U pycaret scikit-learn
# !pip install markupsafe==2.0.1
import jinja2

# %%
from pycaret.classification import *
import xgboost

# %%
df_train = pd.read_csv('train.csv')
df_train
# Out:
#           id  created_at  campaign_var_1  campaign_var_2  products_purchased  \
# 0          1  2021-01-01               1               2                 2.0
# 1          2  2021-01-01               2               1                 2.0
# 2          3  2021-01-01               9               3                 3.0
# 3          4  2021-01-01               6               7                 2.0
# 4          5  2021-01-01               4               6                 NaN
# ...      ...         ...             ...             ...                 ...
# 39156  39157  2021-12-31              11              11                 2.0
# 39157  39158  2021-12-31               3               9                 3.0
# 39158  39159  2021-12-31               8               7                 2.0
# 39159  39160  2021-12-31               7              12                 2.0
# 39160  39161  2021-12-31               2               5                 NaN
#
# ...

# %%
df_train.isna().sum()
# Out:
# id                          0
# created_at                  0
# campaign_var_1              0
# campaign_var_2              0
# products_purchased      20911
# signup_date             15113
# user_activity_var_1         0
# user_activity_var_2         0
# user_activity_var_3         0
# user_activity_var_4         0
# user_activity_var_5         0
# user_activity_var_6         0
# user_activity_var_7         0
# user_activity_var_8         0
# user_activity_var_9         0
# user_activity_var_10        0
# user_activity_var_11        0
# user_activity_var_12        0
# buy                         0
# dtype: int64

# %%
df_train['created_at'] = pd.to_datetime(df_train['created_at'], format = "%Y-%m-%d")
df_train['signup_date'] = pd.to_datetime(df_train['signup_date'], format = "%Y-%m-%d")
df_train['created_at'].dtypes
df_train['signup_date'].dtypes

df_train
# Out:
#           id created_at  campaign_var_1  campaign_var_2  products_purchased  \
# 0          1 2021-01-01               1               2                 2.0
# 1          2 2021-01-01               2               1                 2.0
# 2          3 2021-01-01               9               3                 3.0
# 3          4 2021-01-01               6               7                 2.0
# 4          5 2021-01-01               4               6                 NaN
# ...      ...        ...             ...             ...                 ...
# 39156  39157 2021-12-31              11              11                 2.0
# 39157  39158 2021-12-31               3               9                 3.0
# 39158  39159 2021-12-31               8               7                 2.0
# 39159  39160 2021-12-31               7              12                 2.0
# 39160  39161 2021-12-31               2               5                 NaN
#
# ...

# %%
df_train['created_at_years'] = df_train['created_at'].dt.year
df_train['created_at_month'] = df_train['created_at'].dt.month
df_train['created_at_week'] = df_train['created_at'].dt.week
df_train['created_at_day'] = df_train['created_at'].dt.day
df_train['created_at_dayofweek'] = df_train['created_at'].dt.dayofweek

df_train['signup_date_year'] = df_train['signup_date'].dt.year
df_train['signup_date_month'] = df_train['signup_date'].dt.month
df_train['signup_date_week'] = df_train['signup_date'].dt.week
df_train['signup_date_at_day'] = df_train['signup_date'].dt.day
df_train['signup_date_at_dayofweek'] = df_train['signup_date'].dt.dayofweek

df_train
# Out:
#           id created_at  campaign_var_1  campaign_var_2  products_purchased  \
# 0          1 2021-01-01               1               2                 2.0
# 1          2 2021-01-01               2               1                 2.0
# 2          3 2021-01-01               9               3                 3.0
# 3          4 2021-01-01               6               7                 2.0
# 4          5 2021-01-01               4               6                 NaN
# ...      ...        ...             ...             ...                 ...
# 39156  39157 2021-12-31              11              11                 2.0
# 39157  39158 2021-12-31               3               9                 3.0
# 39158  39159 2021-12-31               8               7                 2.0
# 39159  39160 2021-12-31               7              12                 2.0
# 39160  39161 2021-12-31               2               5                 NaN
#
# ...

# %%
s = setup(data = df_train, target = 'buy', session_id=123, ignore_features = ['created_at','signup_date'],numeric_features = ['products_purchased'], numeric_imputation='mean', categorical_imputation='mode', fix_imbalance = True)
# Out:
#                                Description             Value
# 0                               session_id               123
# 1                                   Target               buy
# 2                              Target Type            Binary
# 3                            Label Encoded              None
# 4                            Original Data       (39161, 29)
# 5                           Missing Values              True
# 6                         Numeric Features                 6
# 7                     Categorical Features                20
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set      (27412, 106)
# 12                    Transformed Test Set      (11749, 106)
# 13                      Shuffle Train-Test              True
# ...

# %%
#Getting the best model
best_model = compare_models(sort = 'F1')
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# et                 Extra Trees Classifier    0.9748  0.9283  0.5534  0.9290
# lightgbm  Light Gradient Boosting Machine    0.9745  0.9449  0.5563  0.9164
# gbc          Gradient Boosting Classifier    0.9741  0.9378  0.5542  0.9075
# catboost              CatBoost Classifier    0.9746  0.9433  0.5435  0.9389
# xgboost         Extreme Gradient Boosting    0.9738  0.9390  0.5591  0.8922
# ada                  Ada Boost Classifier    0.9728  0.9328  0.5683  0.8569
# rf               Random Forest Classifier    0.9736  0.9271  0.5110  0.9561
# dt               Decision Tree Classifier    0.9508  0.7766  0.5825  0.5218
# lr                    Logistic Regression    0.9186  0.9388  0.7728  0.3638
# ridge                    Ridge Classifier    0.8988  0.0000  0.7884  0.3107
# lda          Linear Discriminant Analysis    0.8988  0.9335  0.7884  0.3106
# ...

# %%
print(best_model)
# Out:
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#                      oob_score=False, random_state=123, verbose=0,
#                      warm_start=False)

# %%
#Fine tune the created model
tuned_model = tune_model(best_model)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# Fold
# 0       0.9176  0.9216  0.7394  0.3571  0.4817  0.4427  0.4775
# 1       0.9530  0.9269  0.6197  0.5399  0.5770  0.5523  0.5537
# 2       0.9456  0.9218  0.7163  0.4810  0.5755  0.5477  0.5601
# 3       0.9559  0.9139  0.6667  0.5595  0.6084  0.5852  0.5877
# 4       0.9358  0.9329  0.7163  0.4262  0.5344  0.5023  0.5219
# 5       0.9537  0.9262  0.7376  0.5361  0.6209  0.5969  0.6055
# 6       0.9562  0.9157  0.6099  0.5695  0.5890  0.5659  0.5663
# 7       0.9445  0.9208  0.7092  0.4739  0.5682  0.5398  0.5523
# 8       0.9467  0.9063  0.6312  0.4863  0.5494  0.5216  0.5266
# 9       0.9580  0.9207  0.6620  0.5839  0.6205  0.5983  0.5997
# Mean    0.9467  0.9207  0.6808  0.5013  0.5725  0.5453  0.5551
# Std     0.0117  0.0070  0.0466  0.0674  0.0406  0.0453  0.0370

# %%
df_test = pd.read_csv('test.csv')
df_test
# Out:
#           id  created_at  campaign_var_1  campaign_var_2  products_purchased  \
# 0      39162  2022-01-01               2               2                 NaN
# 1      39163  2022-01-01               4               7                 3.0
# 2      39164  2022-01-01               8               7                 NaN
# 3      39165  2022-01-01               9               8                 2.0
# 4      39166  2022-01-01               4               5                 2.0
# ...      ...         ...             ...             ...                 ...
# 13179  52341  2022-03-30              16              12                 NaN
# 13180  52342  2022-03-30              12               8                 NaN
# 13181  52343  2022-03-30              14              14                 3.0
# 13182  52344  2022-03-30              14              10                 NaN
# 13183  52345  2022-03-30              13              13                 NaN
#
# ...

# %%
df_test['created_at'] = pd.to_datetime(df_test['created_at'], format = "%Y-%m-%d")
df_test['signup_date'] = pd.to_datetime(df_test['signup_date'], format = "%Y-%m-%d")

df_test['created_at_years'] = df_test['created_at'].dt.year
df_test['created_at_month'] = df_test['created_at'].dt.month
df_test['created_at_week'] = df_test['created_at'].dt.week
df_test['created_at_day'] = df_test['created_at'].dt.day
df_test['created_at_dayofweek'] = df_test['created_at'].dt.dayofweek

df_test['signup_date_year'] = df_test['signup_date'].dt.year
df_test['signup_date_month'] = df_test['signup_date'].dt.month
df_test['signup_date_week'] = df_test['signup_date'].dt.week
df_test['signup_date_at_day'] = df_test['signup_date'].dt.day
df_test['signup_date_at_dayofweek'] = df_test['signup_date'].dt.dayofweek

df_test
# Out:
#           id created_at  campaign_var_1  campaign_var_2  products_purchased  \
# 0      39162 2022-01-01               2               2                 NaN
# 1      39163 2022-01-01               4               7                 3.0
# 2      39164 2022-01-01               8               7                 NaN
# 3      39165 2022-01-01               9               8                 2.0
# 4      39166 2022-01-01               4               5                 2.0
# ...      ...        ...             ...             ...                 ...
# 13179  52341 2022-03-30              16              12                 NaN
# 13180  52342 2022-03-30              12               8                 NaN
# 13181  52343 2022-03-30              14              14                 3.0
# 13182  52344 2022-03-30              14              10                 NaN
# 13183  52345 2022-03-30              13              13                 NaN
#
# ...

# %%
#Predictions with best_model (Adaboost in this case)
predictions = predict_model(tuned_model, data = df_test, raw_score = True)
predictions
# Out:
#           id created_at  campaign_var_1  campaign_var_2  products_purchased  \
# 0      39162 2022-01-01               2               2                 NaN
# 1      39163 2022-01-01               4               7                 3.0
# 2      39164 2022-01-01               8               7                 NaN
# 3      39165 2022-01-01               9               8                 2.0
# 4      39166 2022-01-01               4               5                 2.0
# ...      ...        ...             ...             ...                 ...
# 13179  52341 2022-03-30              16              12                 NaN
# 13180  52342 2022-03-30              12               8                 NaN
# 13181  52343 2022-03-30              14              14                 3.0
# 13182  52344 2022-03-30              14              10                 NaN
# 13183  52345 2022-03-30              13              13                 NaN
#
# ...

# %%
#Creating Submission file for Hackathon
pred = pd.DataFrame()
pred[['id','buy']] = predictions[['id','Label']]
pred[['id','buy']].to_csv('output_v4_2.csv',index = False)
